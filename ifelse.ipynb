# %%
number = int(input("Enter the numbers"))

if number == 1: 
    print("Monday")
elif number == 2:
    print("Tuesday")
elif number == 3:
    print("Wednesday")
elif number == 4:
    print("Thursday")
elif number == 5:
    print("Friday")
elif number == 6:
    print("Saturday")
elif number == 7:
    print("Sunday")

else :
    print("no other")
# Out:
# no other

# %%
'''calculator'''


n1 = int(input("Enter the Number N1 "))
n2 = int(input("Enter the Number N2 "))
operator = input("Enter the Operator")

if operator == "+":
    print("Addition of Numbers", n1+n2)
elif operator == "-":
    print("Subtration of Numbers", n1-n2)
elif operator == "*":
    print("Multiplication of Numbers", n1*n2)
elif operator == "/":
    if n2 != 0:

        print("Division of Numbers", n1/n2)
    else:
        print("Division Error")
else:
    print("numbers is invalid")
# Out:
# Division Error

# %%
password = input("create password")
if len(password)>= 8:
    
    if password.isdigit():
        print("password created successfully")
    else:
        print("password should contain alpha") 

    print("password is Strong")
else:
    print("password cannot form")
# Out:
# password created successfully
# password is Strong

# %%
password = input("create password")
if len(password) == 8:
    if password[0:4].isalpha():
        print("Password is correct")
    elif password[4:].isdigit():
        print("Password is Correct")
else:
        print("Password is incorrect")
# Out:
# Password is incorrect

# %%
password = input("create password")
if len(password) == 8:
    if password[0:4].isalpha() and password[4:].isdigit():
        print("Password is correct")
    else:
        print("INVALID ")
else:

    print("password is incorrect")

# %%
rollnumber = input("Create Roll Number")
if len(rollnumber)== 4:
    if rollnumber[0:2].isupper() and rollnumber[0:2].isalpha() and rollnumber[2:].isdigit():
        print("Roll Number is valid")
    else:
        print("invalid format")
else:
    print("roll number is incorrect")
# Out:
# Roll Number is valid

# %%
'''Write a program to check whether a character is:
    - Uppercase letter
    - Lowercase letter
    - Digit
    - Special character'''

charater = input("charater")

if charater.isupper():
    print("character is upper")
elif charater.islower():
    print("character is lower")
elif charater.isdigit():
    print("character is a number")
else:
    print("it as a special character")
# Out:
# it as a special character

# %%
'''Write a program to calculate income tax based on the following conditions:
    - Income ≤ ₹2,50,000 → No tax
    - ₹2,50,001–₹5,00,000 → 5% tax
    - ₹5,00,001–₹10,00,000 → 20% tax
    - Above ₹10,00,000 → 30% tax'''

income = int(input("enter the Amount"))

if income <= 250000:
    print("No tax")
elif income> 250000:
    print("30% tax")
elif income > 500001:
    print("20% Tax")
elif income > 1000000:

    print("30% Tax")
# Out:
# 30% tax

# %%
'''Write a program to check whether three given sides can form a triangle.'''


a = input("Enter the side A ")
b = input("Enter the side B ")
c = input("Enter the side C ")

if (a + b > c) and (a + c > b) and (b + c > a):

   print("These sides CAN form a triangle.")
else:
    print("These sides CANNOT form a triangle.")
# Out:
# These sides CANNOT form a triangle.

# %%
''''Write a program to identify the type of triangle based on its sides:
    - Equilateral
    - Isosceles
    - Scalene
'''

a = input("Enter the side A ")
b = input("Enter the side B ")
c = input("Enter the side C ")

if a == b == c :
    print("IT'S AN EQILATERAL TRIANGLE")

elif a == b or b == c or a == c:
    print("IT'S AN ISOSCELES TRIANGLE")
else:
     print("IT'S AN SCALENE")
# Out:
# IT'S AN EQILATERAL TRIANGLE

# %%
''' Write a program that asks the user to enter a username and password:
    - If both are correct, display "Login Successful".
    - If the username is correct but the password is incorrect, display "Incorrect Password".
    - If the username is incorrect, display "User Not Found".'''


a = input("Enter the username ")
b = input("Enter the Password")

CORRECT_USER = "SUDHI"
CORRECT_PASS = "sudhi123"

if CORRECT_USER == a:
        if CORRECT_PASS == b:
            print("Login Successful")
        else: 
            print("Incorrect Password")
else:
        print("User Not Found")
# Out:
# User Not Found

# %%
''' Write a menu-driven program with the following options:
    1. Check Even/Odd
    2. Find the Largest of Two Numbers
    3. Check Leap Year
    4. Exit'''

# %%
'''Write a program to calculate the discount on a purchase based on the following conditions:
    - Purchase amount ≥ ₹5000 → 20% discount
    - Purchase amount between ₹2000 and ₹4999 → 10% discount
    - Purchase amount below ₹2000 → No discount'''

purchase_amount  = int(input("Enter the amount"))

if purchase_amount >= 5000:
    print(" 20% discount ")
elif  2000 <= purchase_amount <= 4999:
    print("10% discount")
else:
    print("No discount")
# Out:
# No discount

# %%
'''Write a program to determine the result of a student based on marks in three subjects:
    - If the student scores at least 35 marks in all subjects, display "Pass".
    - Otherwise, display "Fail".
    - If the student passes, classify the result based on the average marks:
        - Average ≥ 75 → Distinction
        - Average 60–74 → First Class
        - Average 50–59 → Second Class
        - Average below 50 → Pass Class'''

# %%
'''Write a program to check whether a number is positive or negative.'''

a = int(input("enter the number"))

if a > 0:
    print(" NUMBER IS POSITIVE")
else:
    print(" NUMBER IS NEGATIVE")
# Out:
#  NUMBER IS NEGATIVE

# %%
'''Write a program to check whether a person is eligible to vote (age 18 or above).'''

age = int(input("enter the age "))

minimum_age = 18

if age  >= minimum_age:
    print("Eligible to vote")
else:
    print("not eligible")
# Out:
# Eligible to vote

# %%
'''Enter two numbers and print the greater number'''

num1 = int(input("Enter the num1"))
num2 = int(input("Enter the num2"))

if num1>num2:
    print("num1 is greater")
else:
    print("num2 is greater")
# Out:
# num2 is greater

# %%
'''Write a program to check whether a number is even or odd.'''

n1 = int(input("enter the number1"))

if n1 % 2 == 0:
    print("is even")
else:
    print("is odd")
# Out:
# is odd

# %%
'''Enter a mark and display:
             A grade for 90 and above
             B grade for 75–89
             C grade for 50–74
            Fail for below 50'''


marks = int(input("enter the marks"))

if marks >= 90:
    print("A grade")
elif  75 <= marks <= 89:
    print("B grade")
elif 50 <= marks <= 74:
    print("C grade")
else:
    print("failed")
# Out:
# B grade

# %%
'''Write a program to check whether a character is a vowel or consonant.'''

char = input("Enter the character")

if char in 'aeiou':
    print("is vowel")
else:
    print("consonant")
# Out:
# consonant

# %%
'''Enter three numbers and print the largest number.'''

n1 = int(input("enter the number1"))
n2 = int(input("enter the number2"))
n3 = int(input("enter the number3"))

largest = max(n1,n2,n3)

print(largest)
# Out:
# 4

# %%
'''Write a program to check whether a year is a leap year or not.'''

year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Not a Leap Year

# %%
'''Enter the temperature and display:
             Extreme temp (above 35)
             Warm (20–35)
             Cold (below 20)'''

tem = int(input("enter the tem"))

if tem >35:
    print("Extreme tem ")
elif 20<= tem <= 35:
    print("warm")
else:
    print("cold")
# Out:
# Extreme tem

# %%
'''Write a program to check whether a number is divisible by 5, 3, both, or neither.'''

num = int(input("enter the number "))

if num%5 ==0 and num%3 == 0:
    print("divisible by both")
elif num % 3 == 0:
    print("divisible by 3")
elif num % 5 ==0:
    print("divisible by 5" )
else:
    print("neither")
# Out:
# neither

# %%
'''Write a program to calculate the Body Mass Index (BMI) of a person and display the category:
    - Underweight
    - Normal
    - Overweight
    - Obese'''


weight = float(input("enter the weight"))
height = float(input("enter the height"))

bmi = weight / (height ** 2)

if bmi < 18.5:
    print("Category: Underweight")
elif bmi < 25.0:
    print("Category: Normal")
elif bmi < 30.0:
    print("Category: Overweight")
else:
    print("Category: Obese")
# Out:
# Category: Underweight
