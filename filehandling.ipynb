# %%
file =open("C:\\Users\SUDHI S R\OneDrive\Desktop\demo.txt", "r")
print(file.read())
# Out:
# I am sudhi Sr

# %%
file = open("pytho.txt","w")
file.write(" helo world")
file.close()

# %%
file = open("C:\\Users\SUDHI S R\OneDrive\Desktop\demo.txt","a")
file.write("\n i am studying python AL ML")
file.close()

# %%
file =open("C:\\Users\SUDHI S R\OneDrive\Desktop\demo.txt", "r")
print(file.read())
# Out:
# I am sudhi Sr
#  i am studying python AL ML
#  i am studying python AL ML
#  i am studying python AL ML
#  i am studying python AL ML

# %%
file =open("C:\\Users\SUDHI S R\OneDrive\Desktop\demo.txt", "w")
file.write("\n i am new")
file =open("C:\\Users\SUDHI S R\OneDrive\Desktop\demo.txt", "r")
print(file.read())
# Out:
#  i am new

# %%
file_name = input("enter the name")

try:
    file = open(file_name ,"r")
    print(file.read())
except FileNotFoundError:
    print("Error file not found")
# Out:
# Error file not found
