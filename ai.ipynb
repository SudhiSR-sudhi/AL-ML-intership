# %%
x=5
print(x)
# Out:
# 5

# %%
x = "hello world"
print(x[2])
print(x[2:5])
print(x[2:6:2])
# Out:
# l
# llo
# lo

# %%
x = 2020
y = 2
z = "june"

print(str(x),str(y),z)
print(f"{x} {y} {z}")
# Out:
# 2020 2 june
# 2020 2 june

# %%
x = "Sudhi!" 
print(x.lower())
y = x.replace("!","")
print(y)
# Out:
# sudhi!
# Sudhi

# %%
'''upper case'''

x = "Sudhi" 
print(x.upper())


'''sentence store'''

y = "Hello boy"
print(y)
print(len(y))
print(y[0])
print(y[8])


'''total no of characters '''

b= "Python Programming"
print(len(b))


'''Capital letter of each word'''

text = "hello world"
text = text.replace("hello", "Hello").replace("world", "World")
print(text)



'''replace all spaces in a sentence with -'''

q = "my name is sudhi sr "
print(q)
q.replace(' ','-')




'''movie name in a string and print it in lowercase.'''

x= "Dhurandhar"
print(x.lower())
# Out:
# SUDHI
# Hello boy
# 9
# H
# y
# 18
# Hello World
# my name is sudhi sr
# dhurandhar

# %%
''' print how many times the letter "a" appears.'''

d= "banana"
d.count("a")
# Out:
# 3

# %%
'''check whether the word "Python" exists inside the sentence'''

c= "I am learning Python today"
'Python' in c
# Out:
# True

# %%
'''string with extra spaces at the beginning and end'''

t = "     i am busy today    "
v = t.strip()
print (v)
# Out:
# i am busy today

# %%
''' in a string and split it into separate fruits using a string method.'''

fruit_list = "apple,mango,orange"
w = fruit_list.split(",")
print(w)
# Out:
# ['apple', 'mango', 'orange']

# %%
'''integer boolean float'''
x = 10
y = 20
print(x == y) 
print(x != y)
print(x > y) 
print(x < y) 
print(x >= 10) 
print(y <= 15)
# Out:
# False
# True
# False
# True
# True
# False

# %%
y=10
x="10"
print(type(y))
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %%
'''string concatenation'''
a = "10"
b = "5"
print(a + b)
# Out:
# 105

# %%
'''length and breadth '''
l = float(input("Enter the length of the rectangle: "))
b =int(input("Enter the breadth of the rectangle: "))
area = l * b
perimeter = 2 * (l + b)
print(area)
print("Perimeter of rectangle:", perimeter)

# %%
'''string indexing'''
input = "I was in the hospital "
print(input)
print(input[2])

'''string slicing'''
print(input[3:11])
print(input[-9:-3])

'''string step'''
print(input[3:11:2])

'''reverse a string '''
p = "reflection"
print(p [::-1])
# Out:
# I was in the hospital
# w
# as in th
# hospit
# a nt
# noitcelfer

# %%
'''count the character'''
algorithm = 'Neural Networks'
print(algorithm)
'''length'''
print(len(algorithm))
'''count'''
algorithm.count("al")
'''upper'''
print(algorithm.upper())
'''lower'''
print(algorithm.lower())
# Out:
# Neural Networks
# 15
# NEURAL NETWORKS
# neural networks
