# %%
'''Create a tuple of 5 numbers and print the first number.'''
my_tuple = (1, 2 , 5 ,8)
print(my_tuple)
print(type(my_tuple))
print(my_tuple[0])
# Out:
# (1, 2, 5, 8)
# <class 'tuple'>
# 1

# %%
'''Write a program to create a tuple of student names and print the last name.'''
student = ("rashin","hamza","suraj")
print(student[2])
# Out:
# suraj

# %%
'''Create a tuple (10, 20, 30, 40) and print its length.'''

numbers =  (10, 20, 30, 40)
len(numbers)
# Out:
# 4

# %%
'''Store 5 country names in a tuple and check whether "India" exists in it'''
country = ("india", "china", "russia", "america", "japan")
"india" in country
# Out:
# True

# %%
'''Create a tuple of numbers and print the maximum value.'''

numbers = (1,8,2,5,6,4)
max(numbers)
# Out:
# 8

# %%
''''Write a program to count how many times 5 appears in the tuple (1, 5, 2, 5, 3)'''

numbers = (1, 5, 2, 5, 3)
numbers.count(5)
# Out:
# 2

# %%
'''Create two tuples (1, 2) and (3, 4) and combine them.'''

p = (1, 2)
q = (3, 4)
z = list(zip(p,q))
print(z)
# Out:
# [(1, 3), (2, 4)]

# %%
'''Store 4 animal names in a tuple and print them in sorted order.'''

animal = ("lion","deer","tiger","zebra", "elephant")
sorted(animal)
# Out:
# ['deer', 'elephant', 'lion', 'tiger', 'zebra']

# %%
'''Create a tuple ("Python", "Java", "C++") and print the index of "Java"'''

language = ("Python", "Java", "C++")
java_index = language.index("Java")
print(java_index)
# Out:
# 1

# %%
'''Write a program to convert the tuple (10, 20, 30) into a list.'''

numbers = (10, 20, 30)
numbers_list = list(zip(numbers))
print(numbers_list)
# Out:
# [(10,), (20,), (30,)]

# %%
my_tuple = (1,'a',3)
print(my_tuple)
print(type(my_tuple))
print(len(my_tuple))
# Out:
# (1, 'a', 3)
# <class 'tuple'>
# 3

# %%
city_list = ['Delhi','Patna','Cuttack','Guwahati']
river_list = ['Yamuna','Ganga','Mahanadi','Brahmaputra']

city_and_their_rivers = list(zip(city_list,river_list))
print(city_and_their_rivers)
# Out:
# [('Delhi', 'Yamuna'), ('Patna', 'Ganga'), ('Cuttack', 'Mahanadi'), ('Guwahati', 'Brahmaputra')]
