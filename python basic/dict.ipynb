# %%
'''Create a dictionary with keys "name" and "age" and print the values.'''
dic1 = {"name":"sudhi" , "age": 23}
print(dic1)
# Out:
# {'name': 'sudhi', 'age': 23}

# %%
'''Write a program to create a dictionary of student details and print the student's name'''

student_detail  = {"name": "rahul", "admission no": 1245, "class": 10 , "division": "C"}
print(student_detail["name"])
# Out:
# rahul

# %%
'''Create a dictionary of 3 subjects and marks, then print all the keys'''
student_mark = {"English": 25, "Hindi": 24, "Maths": 22}
print(student_mark.keys())
# Out:
# dict_keys(['English', 'Hindi', 'Maths'])

# %%
'''Write a program to add a new key "city" to a dictionary.'''

student_mark["city"] = "mumbai"
print(student_mark)
# Out:
# {'English': 25, 'Hindi': 24, 'Maths': 22, 'city': 'mumbai'}

# %%
'''Create a dictionary {"a": 10, "b": 20} and change the value of "b" to 50'''

value = {"a": 10, "b": 20}
value["b"]= 50
print(value)
# Out:
# {'a': 10, 'b': 50}

# %%
'''Write a program to remove the key "age" from a dictionary'''
dic1 = {"name":"sudhi" , "age": 23}
dic1.pop("age") 
print(dic1)
# Out:
# {'name': 'sudhi'}

# %%
'''Create a dictionary of employee details and print all values.'''

employee = {'name': 'Sarah', 'role': 'Software Engineer', 'department': 'IT', 'salary': 75000}
print(employee.values())
# Out:
# dict_values(['Sarah', 'Software Engineer', 'IT', 75000])

# %%
'''Write a program to check whether the key "salary" exists in a dictionary.'''
employee = {'name': 'Sarah', 'role': 'Software Engineer', 'department': 'IT', 'salary': 75000}
"salary" in employee
# Out:
# True

# %%
'''Create two dictionaries and combine them into one dictionary.'''

dict1 = {"name": "Alice", "role": "Developer"}
dict2 = {"city": "Boston", "salary": 85000}

dict1|dict2
# Out:
# {'name': 'Alice', 'role': 'Developer', 'city': 'Boston', 'salary': 85000}

# %%
'''Write a program to print the total number of key-value pairs in a dictionary.'''

dict1 = {"name": "Alice", "role": "Developer"}
len(dict1)
# Out:
# 2
