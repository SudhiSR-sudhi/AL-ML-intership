# %%
'''Create a list of 5 subject names and print the first subject.'''
my_list = ["English","Hindi","Malayalam" ]
print(my_list)
print(my_list[0])
# Out:
# ['English', 'Hindi', 'Malayalam']
# English

# %%
"Write a program to create a list of numbers and print the last element."
print(my_list[2])
# Out:
# Malayalam

# %%
"Create a list of mobile brands and add one new brand using a list method."
my_list2  = ["vivo","oppo", "samsung"]
print(my_list2)
my_list2.append("real me")
print(my_list2)
# Out:
# ['vivo', 'oppo', 'samsung']
# ['vivo', 'oppo', 'samsung', 'real me']

# %%
'''Store 5 student names in a list and print the total number of names.'''

student = ["sooraj","surya","fathima","joseph","hamza"]
len(student)
# Out:
# 5

# %%
'''Create a list [10, 20, 30, 40] and change 30 to 35.'''
list = [10, 20, 30, 40]
list[2] = 35
print(list)
# Out:
# [10, 20, 35, 40]

# %%
'''Write a program to remove "Maths" from the list ["Science", "Maths", "English"]'''

subject = ["Science", "Maths", "English"]
subject.remove("Maths")
print(subject)
# Out:
# ['Science', 'English']

# %%
'''Create a list of numbers and print the maximum value.'''
numbers = [1,5,6,8,9,4]
print(max(numbers))
print(sum(numbers))
# Out:
# 9
# 33

# %%
'''Store 5 city names in a list and print them in alphabetical order.'''
city = ["mumbai","Trivandrum","Banglore","kochi","kolkata"]
sorted(city)
# Out:
# ['Banglore', 'Trivandrum', 'kochi', 'kolkata', 'mumbai']

# %%
'''Create two lists [1, 2, 3] and [4, 5, 6] and combine them into one list.'''

list1 = [1, 2, 3]
list2 = [4, 5, 6]

list1.extend(list2)

print(list1)

'''nested way'''
list1 = [1, 2, 3]
list2 = [4, 5, 6]

list_of_list = (list1,list2)
print(list_of_list)
# Out:
# [1, 2, 3, 4, 5, 6]
# ([1, 2, 3], [4, 5, 6])

# %%
"""Write a program to check whether "pen" exists in the list ["book", "pen", "pencil"]"""

list = ["book", "pen", "pencil"]
print ("pen" in list)
# Out:
# True

# %%
my_string = ("sentence word")
my_string.split()
# Out:
# ['sentence', 'word']

# %%
my_list = ["anu", "rahul", "hema"]

a = ",".join(my_list)
print(a)

print(type(a))
# Out:
# anu,rahul,hema
# <class 'str'>

# %%
'''merge'''
d1 = {"a": 1, "b": 2}
d2 = {"c": 3, "d": 4}

d1.update(d2)
print(d1)
print(d1|d2)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
list1 = [1,2,5,2,4,8,2]

final = set(list1)
print(final)
# Out:
# {1, 2, 4, 5, 8}

# %%
a = d1.values()
tuple1 = tuple(a)
print(tuple1)
# Out:
# (1, 2, 3, 4)

# %%
s= d1.copy()
print(s)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
